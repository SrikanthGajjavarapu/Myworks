# %% [markdown]
# <a href="https://colab.research.google.com/github/SrikanthGajjavarapu/SrikanthGajjavarapu/blob/main/Project4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Weather prediction using ML GaussianNB Model**

# %%
import pandas as pd

# %%
wt=pd.read_csv('weather.csv')

# %%
wt.head()
# Out:
#     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes
# 4     rainy        mild     high  False  yes

# %%
wt.describe()
# Out:
#        outlook temperature humidity  windy play
# count       14          14       14     14   14
# unique       3           3        2      2    2
# top      rainy        mild     high  False  yes
# freq         5           6        7      8    9

# %%
from sklearn.preprocessing import LabelEncoder
numerics=LabelEncoder()

# %%
inputs=wt.drop('play',axis='columns')
target=wt['play']
target
# Out:
# 0     yes
# 1     yes
# 2     yes
# 3     yes
# 4     yes
# 5     yes
# 6      no
# 7     yes
# 8      no
# 9      no
# 10     no
# 11     no
# 12    yes
# 13    yes
# Name: play, dtype: object

# %%
inputs['outlook_n']=numerics.fit_transform(inputs['outlook'])
inputs['temperature_n']=numerics.fit_transform(inputs['temperature'])
inputs['humidity_n']=numerics.fit_transform(inputs['humidity'])
inputs['windy_n']=numerics.fit_transform(inputs['windy'])
inputs
# Out:
#      outlook temperature humidity  windy  outlook_n  temperature_n  \
# 0   overcast         hot     high  False          0              1
# 1   overcast        cool   normal   True          0              0
# 2   overcast        mild     high   True          0              2
# 3   overcast         hot   normal  False          0              1
# 4      rainy        mild     high  False          1              2
# 5      rainy        cool   normal  False          1              0
# 6      rainy        cool   normal   True          1              0
# 7      rainy        mild   normal  False          1              2
# 8      rainy        mild     high   True          1              2
# 9      sunny         hot     high  False          2              1
# 10     sunny         hot     high   True          2              1
# 11     sunny        mild     high  False          2              2
# 12     sunny        cool   normal  False          2              0
# 13     sunny        mild   normal   True          2              2
#
#     humidity_n  windy_n
# 0            0        0
# 1            1        1
# 2            0        1
# 3            1        0
# 4            0        0
# 5            1        0
# 6            1        1
# 7            1        0
# 8            0        1
# 9            0        0
# 10           0        1
# 11           0        0
# 12           1        0
# 13           1        1

# %%
inputs_n=inputs.drop(['outlook','temperature','humidity','windy'],axis='columns')
inputs_n
# Out:
#     outlook_n  temperature_n  humidity_n  windy_n
# 0           0              1           0        0
# 1           0              0           1        1
# 2           0              2           0        1
# 3           0              1           1        0
# 4           1              2           0        0
# 5           1              0           1        0
# 6           1              0           1        1
# 7           1              2           1        0
# 8           1              2           0        1
# 9           2              1           0        0
# 10          2              1           0        1
# 11          2              2           0        0
# 12          2              0           1        0
# 13          2              2           1        1

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(inputs_n,target)
# Out:
# GaussianNB()

# %%
classifier.score(inputs_n,target)
# Out:
# 0.9285714285714286

# %%
w=classifier.predict([[2,1,0,0]])
w
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   "X does not have valid feature names, but"
# array(['no'], dtype='<U3')

# %%
if w[0]=='yes':
  print("The game will happens tomorrow")
else:
  print("The game will not happens tomorrow")
# Out:
# The game will not happens tomorrow
